# %%
#seaborn excersises

# %%
Use the iris database to answer the following quesitons:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pydataset import data
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# What does the distribution of petal lengths look like?

# %%
sns.histplot(iris.petal_length)
plt.show()

# %%
sns.displot(data = iris, x = 'petal_length', kde = True)

# %% [markdown]
# Is there a correlation between petal length and petal width? Use http://guessthecorrelation.com/ as a hint to how we could visually determine if a correlation exists between two numeric columns.

# %%
sns.relplot(data = iris, x = 'petal_length', y = 'petal_width')

# %%
#based on this it does look like there is a positive correlation

# %% [markdown]
# Would it be reasonable to predict species based on sepal width and sepal length? For this, you'll visualize two numeric columns through the lense of a categorical column.

# %%
sns.relplot(x='sepal_width', y='sepal_length', col='species', data=iris)

# %%
#i would say not because the sertosa looks very simmilr to veriscolor

# %% [markdown]
# Which features would be best used to predict species?

# %%
sns.relplot(x='petal_width', y='petal_length', col='species', data=iris)

# %%
#the petal with and length all three species are deffitly grouped in diffrent groups houghout the chart

# %%
########################################################

# %% [markdown]
# Using the lesson as an example, use seaborn's load_dataset function to load the anscombe data set. Use pandas to group the data by the dataset column, and calculate summary statistics for each dataset. What do you notice?
#
# Plot the x and y values from the anscombe data. Each dataset should be in a separate column.

# %%
anscombe = sns.load_dataset('anscombe')

anscombe.dtypes
# Out:
# dataset     object
# x          float64
# y          float64
# dtype: object

# %%
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %% [markdown]
# Plot the x and y values from the anscombe data. Each dataset should be in a separate column.

# %%
sns.relplot(x='x', y='y', hue='x', data=anscombe)

# %%
sns.relplot(x='x',y='y',hue='dataset',col='dataset',data=anscombe)

# %% [markdown]
# Load the InsectSprays dataset and read it's documentation. Create a boxplot that shows the effectiveness of the different insect sprays.

# %%
from pydataset import data

# %%
InsectSprays = data('InsectSprays')

# %%
InsectSprays
# Out:
#     count spray
# 1      10     A
# 2       7     A
# 3      20     A
# 4      14     A
# 5      14     A
# 6      12     A
# 7      10     A
# 8      23     A
# 9      17     A
# 10     20     A
# 11     14     A
# 12     13     A
# 13     11     B
# 14     17     B
# 15     21     B
# 16     11     B
# 17     16     B
# 18     14     B
# 19     17     B
# 20     17     B
# 21     19     B
# 22     21     B
# 23      7     B
# 24     13     B
# 25      0     C
# 26      1     C
# 27      7     C
# 28      2     C
# 29      3     C
# 30      1     C
# 31      2     C
# 32      1     C
# 33      3     C
# 34      0     C
# 35      1     C
# 36      4     C
# 37      3     D
# 38      5     D
# 39     12     D
# 40      6     D
# 41      4     D
# 42      3     D
# 43      5     D
# 44      5     D
# 45      5     D
# 46      5     D
# 47      2     D
# 48      4     D
# 49      3     E
# 50      5     E
# 51      3     E
# 52      5     E
# 53      3     E
# 54      6     E
# 55      1     E
# 56      1     E
# 57      3     E
# 58      2     E
# 59      6     E
# 60      4     E
# 61     11     F
# 62      9     F
# 63     15     F
# 64     22     F
# 65     15     F
# 66     16     F
# 67     13     F
# 68     10     F
# 69     26     F
# 70     26     F
# 71     24     F
# 72     13     F

# %% [markdown]
# Create a boxplot that shows the effectiveness of the different insect sprays.

# %%
sns.boxplot(data=InsectSprays, y='count', x='spray')
# Out:
# <AxesSubplot:xlabel='spray', ylabel='count'>

# %% [markdown]
# Load the swiss dataset and read it's documentation.
#
# The swiss dataset is available from pydatset rather than seaborn.

# %%
swiss = data('swiss')
swiss
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
# Porrentruy         76.1         35.3            9          7     90.57
# Broye              83.8         70.2           16          7     92.85
# Glane              92.4         67.8           14          8     97.16
# Gruyere            82.4         53.3           12          7     97.67
# Sarine             82.9         45.2           16         13     91.38
# Veveyse            87.1         64.5           14          6     98.61
# Aigle              64.1         62.0           21         12      8.52
# Aubonne            66.9         67.5           14          7      2.27
# Avenches           68.9         60.7           19         12      4.43
# Cossonay           61.7         69.3           22          5      2.82
# Echallens          68.3         72.6           18          2     24.20
# Grandson           71.7         34.0           17          8      3.30
# Lausanne           55.7         19.4           26         28     12.11
# La Vallee          54.3         15.2           31         20      2.15
# Lavaux             65.1         73.0           19          9      2.84
# Morges             65.5         59.8           22         10      5.23
# Moudon             65.0         55.1           14          3      4.52
# Nyone              56.6         50.9           22         12     15.14
# Orbe               57.4         54.1           20          6      4.20
# Oron               72.5         71.2           12          1      2.40
# Payerne            74.2         58.1           14          8      5.23
# Paysd'enhaut       72.0         63.5            6          3      2.56
# Rolle              60.5         60.8           16         10      7.72
# Vevey              58.3         26.8           25         19     18.46
# Yverdon            65.4         49.5           15          8      6.10
# Conthey            75.5         85.9            3          2     99.71
# Entremont          69.3         84.9            7          6     99.68
# Herens             77.3         89.7            5          2    100.00
# Martigwy           70.5         78.2           12          6     98.96
# Monthey            79.4         64.9            7          3     98.22
# St Maurice         65.0         75.9            9          9     99.06
# Sierre             92.2         84.6            3          3     99.46
# Sion               79.3         63.1           13         13     96.83
# Boudry             70.4         38.4           26         12      5.62
# La Chauxdfnd       65.7          7.7           29         11     13.79
# Le Locle           72.7         16.7           22         13     11.22
# Neuchatel          64.4         17.6           35         32     16.92
# Val de Ruz         77.6         37.6           15          7      4.97
# ValdeTravers       67.6         18.7           25          7      8.65
# V. De Geneve       35.0          1.2           37         53     42.34
# Rive Droite        44.7         46.6           16         29     50.43
# Rive Gauche        42.8         27.7           22         29     58.33
#
#               Infant.Mortality
# Courtelary                22.2
# Delemont                  22.2
# Franches-Mnt              20.2
# Moutier                   20.3
# Neuveville                20.6
# Porrentruy                26.6
# Broye                     23.6
# Glane                     24.9
# Gruyere                   21.0
# Sarine                    24.4
# Veveyse                   24.5
# Aigle                     16.5
# Aubonne                   19.1
# Avenches                  22.7
# Cossonay                  18.7
# Echallens                 21.2
# Grandson                  20.0
# Lausanne                  20.2
# La Vallee                 10.8
# Lavaux                    20.0
# Morges                    18.0
# Moudon                    22.4
# Nyone                     16.7
# Orbe                      15.3
# Oron                      21.0
# Payerne                   23.8
# Paysd'enhaut              18.0
# Rolle                     16.3
# Vevey                     20.9
# Yverdon                   22.5
# Conthey                   15.1
# Entremont                 19.8
# Herens                    18.3
# Martigwy                  19.4
# Monthey                   20.2
# St Maurice                17.8
# Sierre                    16.3
# Sion                      18.1
# Boudry                    20.3
# La Chauxdfnd              20.5
# Le Locle                  18.9
# Neuchatel                 23.0
# Val de Ruz                20.0
# ValdeTravers              19.5
# V. De Geneve              18.0
# Rive Droite               18.2
# Rive Gauche               19.3

# %% [markdown]
# Create visualizations to answer the following questions:
#
# Create an attribute named is_catholic that holds a boolean value
# of whether or not the province is Catholic.
# (Choose a cutoff point for what constitutes catholic)
#
#
# Does whether or not a province is Catholic influence fertility?
# What measure correlates most strongly with fertility?

# %%
swiss.Catholic > 50
# Out:
# Courtelary      False
# Delemont         True
# Franches-Mnt     True
# Moutier         False
# Neuveville      False
# Porrentruy       True
# Broye            True
# Glane            True
# Gruyere          True
# Sarine           True
# Veveyse          True
# Aigle           False
# Aubonne         False
# Avenches        False
# Cossonay        False
# Echallens       False
# Grandson        False
# Lausanne        False
# La Vallee       False
# Lavaux          False
# Morges          False
# Moudon          False
# Nyone           False
# Orbe            False
# Oron            False
# Payerne         False
# Paysd'enhaut    False
# Rolle           False
# Vevey           False
# Yverdon         False
# Conthey          True
# Entremont        True
# Herens           True
# Martigwy         True
# Monthey          True
# St Maurice       True
# Sierre           True
# Sion             True
# Boudry          False
# La Chauxdfnd    False
# Le Locle        False
# Neuchatel       False
# Val de Ruz      False
# ValdeTravers    False
# V. De Geneve    False
# Rive Droite      True
# Rive Gauche      True
# Name: Catholic, dtype: bool

# %%
swiss['is_catholic'] = swiss.Catholic > 50

# %%
swiss
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
# Porrentruy         76.1         35.3            9          7     90.57
# Broye              83.8         70.2           16          7     92.85
# Glane              92.4         67.8           14          8     97.16
# Gruyere            82.4         53.3           12          7     97.67
# Sarine             82.9         45.2           16         13     91.38
# Veveyse            87.1         64.5           14          6     98.61
# Aigle              64.1         62.0           21         12      8.52
# Aubonne            66.9         67.5           14          7      2.27
# Avenches           68.9         60.7           19         12      4.43
# Cossonay           61.7         69.3           22          5      2.82
# Echallens          68.3         72.6           18          2     24.20
# Grandson           71.7         34.0           17          8      3.30
# Lausanne           55.7         19.4           26         28     12.11
# La Vallee          54.3         15.2           31         20      2.15
# Lavaux             65.1         73.0           19          9      2.84
# Morges             65.5         59.8           22         10      5.23
# Moudon             65.0         55.1           14          3      4.52
# Nyone              56.6         50.9           22         12     15.14
# Orbe               57.4         54.1           20          6      4.20
# Oron               72.5         71.2           12          1      2.40
# Payerne            74.2         58.1           14          8      5.23
# Paysd'enhaut       72.0         63.5            6          3      2.56
# Rolle              60.5         60.8           16         10      7.72
# Vevey              58.3         26.8           25         19     18.46
# Yverdon            65.4         49.5           15          8      6.10
# Conthey            75.5         85.9            3          2     99.71
# Entremont          69.3         84.9            7          6     99.68
# Herens             77.3         89.7            5          2    100.00
# Martigwy           70.5         78.2           12          6     98.96
# Monthey            79.4         64.9            7          3     98.22
# St Maurice         65.0         75.9            9          9     99.06
# Sierre             92.2         84.6            3          3     99.46
# Sion               79.3         63.1           13         13     96.83
# Boudry             70.4         38.4           26         12      5.62
# La Chauxdfnd       65.7          7.7           29         11     13.79
# Le Locle           72.7         16.7           22         13     11.22
# Neuchatel          64.4         17.6           35         32     16.92
# Val de Ruz         77.6         37.6           15          7      4.97
# ValdeTravers       67.6         18.7           25          7      8.65
# V. De Geneve       35.0          1.2           37         53     42.34
# Rive Droite        44.7         46.6           16         29     50.43
# Rive Gauche        42.8         27.7           22         29     58.33
#
#               Infant.Mortality  is_catholic
# Courtelary                22.2        False
# Delemont                  22.2         True
# Franches-Mnt              20.2         True
# Moutier                   20.3        False
# Neuveville                20.6        False
# Porrentruy                26.6         True
# Broye                     23.6         True
# Glane                     24.9         True
# Gruyere                   21.0         True
# Sarine                    24.4         True
# Veveyse                   24.5         True
# Aigle                     16.5        False
# Aubonne                   19.1        False
# Avenches                  22.7        False
# Cossonay                  18.7        False
# Echallens                 21.2        False
# Grandson                  20.0        False
# Lausanne                  20.2        False
# La Vallee                 10.8        False
# Lavaux                    20.0        False
# Morges                    18.0        False
# Moudon                    22.4        False
# Nyone                     16.7        False
# Orbe                      15.3        False
# Oron                      21.0        False
# Payerne                   23.8        False
# Paysd'enhaut              18.0        False
# Rolle                     16.3        False
# Vevey                     20.9        False
# Yverdon                   22.5        False
# Conthey                   15.1         True
# Entremont                 19.8         True
# Herens                    18.3         True
# Martigwy                  19.4         True
# Monthey                   20.2         True
# St Maurice                17.8         True
# Sierre                    16.3         True
# Sion                      18.1         True
# Boudry                    20.3        False
# La Chauxdfnd              20.5        False
# Le Locle                  18.9        False
# Neuchatel                 23.0        False
# Val de Ruz                20.0        False
# ValdeTravers              19.5        False
# V. De Geneve              18.0        False
# Rive Droite               18.2         True
# Rive Gauche               19.3         True

# %% [markdown]
# Does whether or not a province is Catholic influence fertility?

# %%
sns.relplot(x='Catholic',y='Fertility', hue ='is_catholic', data=swiss)

# %%
#not really, although being catholic looks slightly higher but not by much

# %% [markdown]
# What measure correlates most strongly with fertility?

# %%
sns.relplot(x='Agriculture',y='Fertility', data=swiss)

# %%
sns.relplot(x='Examination',y='Fertility', data=swiss)

# %%
sns.relplot(x='Education',y='Fertility', data=swiss)

# %% [markdown]
# Using the chipotle dataset from the previous exercise, create a bar chart that shows the 4 most popular items and the revenue produced by each.

# %%
from env import host, user, password

get_db_url = f'mysql+pymysql://{user}:{password}@{host}/chipotle'

# %%
orders = pd.read_sql('SELECT * FROM orders', get_db_url)
orders
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   nan     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   nan     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 6 columns]

# %%
##price = orders['item_price'] = orders.item_price.str.replace('$', '')
# Out:
# /var/folders/f1/8blv52r50y1cffy2qpp05b5c0000gn/T/ipykernel_44092/1084436701.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   price = orders['item_price'] = orders.item_price.str.replace('$', '')

# %%
orders['item_price'] = orders.item_price.str.replace('$', '').astype('float')
# Out:
# /var/folders/f1/8blv52r50y1cffy2qpp05b5c0000gn/T/ipykernel_49674/3139485877.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   orders['item_price'] = orders.item_price.str.replace('$', '').astype('float')

# %%
orders.head(6)
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
# 5   6         3         1                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                nan        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                nan        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98

# %%
best_sellers = orders.groupby('item_name').quantity.sum().nlargest(4)
best_sellers
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Name: quantity, dtype: int64

# %%
orders[orders.item_name.isin(best_sellers.index)]
# Out:
#         id  order_id  quantity            item_name  \
# 4        5         2         2         Chicken Bowl
# 5        6         3         1         Chicken Bowl
# 7        8         4         1        Steak Burrito
# 9       10         5         1        Steak Burrito
# 10      11         5         1  Chips and Guacamole
# ...    ...       ...       ...                  ...
# 4607  4608      1829         1        Steak Burrito
# 4610  4611      1830         1        Steak Burrito
# 4616  4617      1832         1  Chips and Guacamole
# 4617  4618      1833         1        Steak Burrito
# 4618  4619      1833         1        Steak Burrito
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        9.25
# 10                                                  nan        4.45
# ...                                                 ...         ...
# 4607  [Tomatillo Green Chili Salsa, [Rice, Cheese, S...       11.75
# 4610  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4616                                                nan        4.45
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
#
# [2126 rows x 6 columns]

# %%
revenue = orders[orders.item_name.isin(best_sellers.index)].groupby('item_name').item_price.sum()
revenue
# Out:
# item_name
# Chicken Bowl           7342.73
# Chicken Burrito        5575.82
# Chips and Guacamole    2201.04
# Steak Burrito          3851.43
# Name: item_price, dtype: float64

# %%
revenue = revenue.sort_values(ascending = False).reset_index()
revenue
# Out:
#              item_name  item_price
# 0         Chicken Bowl     7342.73
# 1      Chicken Burrito     5575.82
# 2        Steak Burrito     3851.43
# 3  Chips and Guacamole     2201.04

# %%
plt.figure(figsize = (8, 5))
sns.barplot(y = 'item_name',
            x = 'item_price',
            data = revenue,
            palette=['#451400'])

plt.title('Most popular items and revenue', fontdict={'color': '#a81612'})

plt.ylabel("") # to remove the column_name
plt.xlabel("Gross Revenue")
# Out:
# Text(0.5, 0, 'Gross Revenue')

# %% [markdown]
# 5. Load the sleepstudy data and read it's documentation. Use seaborn to create a line chart of all the individual subject's reaction times and a more prominant line showing the average change in reaction time.

# %%
sleepstudy = data('sleepstudy')

# %%
sleepstudy.head()
# Out:
#    Reaction  Days  Subject
# 1  249.5600     0      308
# 2  258.7047     1      308
# 3  250.8006     2      308
# 4  321.4398     3      308
# 5  356.8519     4      308

# %%
sleepstudy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180 entries, 1 to 180
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Reaction  180 non-null    float64
#  1   Days      180 non-null    int64
#  2   Subject   180 non-null    int64
# dtypes: float64(1), int64(2)
# memory usage: 5.6 KB

# %%
sleepstudy['Subject'] = 'Subject_' + sleepstudy.Subject.astype(str)

# %%
sleepstudy.head()
# Out:
#    Reaction  Days      Subject
# 1  249.5600     0  Subject_308
# 2  258.7047     1  Subject_308
# 3  250.8006     2  Subject_308
# 4  321.4398     3  Subject_308
# 5  356.8519     4  Subject_308

# %%
plt.figure(figsize=(10, 8))

sns.lineplot(data = sleepstudy, x = 'Days', y = 'Reaction',  hue = 'Subject')
sns.lineplot(data = sleepstudy, x = 'Days', y = 'Reaction', color = 'black')
# Out:
# <AxesSubplot:xlabel='Days', ylabel='Reaction'>
